# %%
import pandas as pd

# %% [markdown]
# pandas --> take list or 1-dimensional  as Series and 2-dimensional as DataFrames

# %%
#1 -dimensional
series=["BMW","Ferrari","Hyundai","Rolls-Royce","Bugati","Mercedes-Benz"]

# %%
series
# Out:
# ['BMW', 'Ferrari', 'Hyundai', 'Rolls-Royce', 'Bugati', 'Mercedes-Benz']

# %%
series=pd.Series(series)

# %%
series
# Out:
# 0              BMW
# 1          Ferrari
# 2          Hyundai
# 3      Rolls-Royce
# 4           Bugati
# 5    Mercedes-Benz
# dtype: object

# %%
colors=pd.Series(["Blue","Yellow","Maroon","White","Blue","Black","orange"])

# %%
colors
# Out:
# 0      Blue
# 1    Yellow
# 2    Maroon
# 3     White
# 4      Blue
# 5     Black
# 6    orange
# dtype: object

# %%
car_data=pd.DataFrame({"Car_brand":series,"Color":colors})
car_data
# Out:
#        Car_brand   Color
# 0            BMW    Blue
# 1        Ferrari  Yellow
# 2        Hyundai  Maroon
# 3    Rolls-Royce   White
# 4         Bugati    Blue
# 5  Mercedes-Benz   Black
# 6            NaN  orange

# %%
car_csv=pd.read_csv("data/7.1 car-sales.csv")
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_csv.to_csv("new_car_sales.csv",index=0)

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
new_car_sales=pd.read_csv("new_car_sales.csv")
new_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ##Describe data

# %%
car_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_csv.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_csv.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_csv.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_csv["Doors"].sum()
# Out:
# 40

# %%
car_csv["Doors"].mean()
# Out:
# 4.0

# %%
data=car_csv.describe()

# %%
data
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["Doors"]
# Out:
# count    10.000000
# mean      4.000000
# std       0.471405
# min       3.000000
# 25%       4.000000
# 50%       4.000000
# 75%       4.000000
# max       5.000000
# Name: Doors, dtype: float64

# %% [markdown]
# ## LOC and ILOC

# %%
car_data
# Out:
#        Car_brand   Color
# 0            BMW    Blue
# 1        Ferrari  Yellow
# 2        Hyundai  Maroon
# 3    Rolls-Royce   White
# 4         Bugati    Blue
# 5  Mercedes-Benz   Black
# 6            NaN  orange

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Car_brand  6 non-null      object
#  1   Color      7 non-null      object
# dtypes: object(2)
# memory usage: 244.0+ bytes

# %%
car_data.loc[:4]
# Out:
#      Car_brand   Color
# 0          BMW    Blue
# 1      Ferrari  Yellow
# 2      Hyundai  Maroon
# 3  Rolls-Royce   White
# 4       Bugati    Blue

# %%
car_data.iloc[4]
# Out:
# Car_brand    Bugati
# Color          Blue
# Name: 4, dtype: object

# %%
car_csv.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_data.head(8)
# Out:
#        Car_brand   Color
# 0            BMW    Blue
# 1        Ferrari  Yellow
# 2        Hyundai  Maroon
# 3    Rolls-Royce   White
# 4         Bugati    Blue
# 5  Mercedes-Benz   Black
# 6            NaN  orange

# %%
car_data.iloc[:3]
# Out:
#   Car_brand   Color
# 0       BMW    Blue
# 1   Ferrari  Yellow
# 2   Hyundai  Maroon

# %%
car_data.loc[:3]
# Out:
#      Car_brand   Color
# 0          BMW    Blue
# 1      Ferrari  Yellow
# 2      Hyundai  Maroon
# 3  Rolls-Royce   White

# %%
car_data.head(4)
# Out:
#      Car_brand   Color
# 0          BMW    Blue
# 1      Ferrari  Yellow
# 2      Hyundai  Maroon
# 3  Rolls-Royce   White

# %%
car_csv.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_csv.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
animals=pd.DataFrame({"name":["cheetah","tiger","lion"],"child":["cheet","cub","lion cub"]},index=[1,43,4])
animals
# Out:
#        name     child
# 1   cheetah     cheet
# 43    tiger       cub
# 4      lion  lion cub

# %%
animals.loc[:43]
# Out:
#        name  child
# 1   cheetah  cheet
# 43    tiger    cub

# %%
animals.iloc[:5]
# Out:
#        name     child
# 1   cheetah     cheet
# 43    tiger       cub
# 4      lion  lion cub

# %%
animals.head(6)
# Out:
#        name     child
# 1   cheetah     cheet
# 43    tiger       cub
# 4      lion  lion cub

# %%
animals.tail()
# Out:
#        name     child
# 1   cheetah     cheet
# 43    tiger       cub
# 4      lion  lion cub

# %%
car_csv["Make"][car_csv.Make=="Honda"]
# Out:
# 1    Honda
# 6    Honda
# 7    Honda
# Name: Make, dtype: object

# %%
car_csv[car_csv["Odometer (KM)"]>90099]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_csv.Make,car_csv.Colour)
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
car_csv["Doors"].plot();

# %%
car_csv["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as mp

# %%
car_csv.Make.hist()
# Out:
# <Axes: >

# %%
car_csv["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
dataframe['amount']= dataframe['amount'].str.replace('[\$\,\.]', '').astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/1p/_1p_43jd4qgcqhcndp34m8pr0000gn/T/ipykernel_69599/3117936513.py:1: SyntaxWarning: invalid escape sequence '\$'
#   dataframe['amount']= dataframe['amount'].str.replace('[\$\,\.]', '').astype(int)
# /var/folders/1p/_1p_43jd4qgcqhcndp34m8pr0000gn/T/ipykernel_69599/3117936513.py:1: SyntaxWarning: invalid escape sequence '\$'
#   dataframe['amount']= dataframe['amount'].str.replace('[\$\,\.]', '').astype(int)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 dataframe['amount']= dataframe['amount'].str.replace('[\$\,\.]', '').astype(int)
#
# NameError: name 'dataframe' is not defined

# %%
car_csv=pd.read_csv("data/7.1 car-sales.csv")

# %%
car_csv['Price'] = car_csv['Price'].str.replace('$', '',regex=0).str.replace(",","",regex=0).astype(float).astype(int)

# %%
car_csv['Price'] = car_csv['Price'].str.replace("$","").str.replace(",","").astype(float).astype(int)

# %%
car_csv["Price"]=car_csv["Price"].str.replace('(/$/,/.)',"")

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_csv.Price.plot()
# Out:
# <Axes: >

# %%
car_csv.Price.hist()
# Out:
# <Axes: >

# %%
## Groupby

# %% [markdown]
# Manipulating Data

# %%
car_csv.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_csv.Make.str.isalpha()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Make, dtype: bool

# %%
car_miss=pd.read_csv("data/car-sales-missing-data.csv")

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_miss["Make"].fillna("BMW",inplace=True)
# Out:
# /var/folders/1p/_1p_43jd4qgcqhcndp34m8pr0000gn/T/ipykernel_69599/1671413836.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_miss["Make"].fillna("BMW",inplace=True)

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     BMW  White   31600.0    4.0   $9,700

# %%
car_miss.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 9     BMW  White   31600.0    4.0   $9,700

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     BMW  White   31600.0    4.0   $9,700

# %%
car_miss.dropna(inplace=True)

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 9     BMW  White   31600.0    4.0   $9,700

# %%
car_miss=pd.read_csv("data/car-sales-missing-data.csv")

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_miss_drop=car_miss.dropna()
car_miss_drop.to_csv("car_miss_drop.csv",index=0)
car_miss_dropped=pd.read_csv("car_miss_drop.csv")
car_miss_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2     BMW  Black   11179.0    5.0  $22,000
# 3  Nissan  White  213095.0    4.0   $3,500

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_miss["Make"]=car_miss["Make"].fillna(car_miss["Make"][3])

# %%
car_miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     BMW  White   31600.0    4.0   $9,700

# %%
car_miss["Make"][9]
# Out:
# 'BMW'

# %%
car_csv["Seats"]=pd.Series([5,5,5,5,5])

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    NaN
# 6   Honda   Blue          45698      4   7500    NaN
# 7   Honda   Blue          54738      4   7000    NaN
# 8  Toyota  White          60000      4   6250    NaN
# 9  Nissan  White          31600      4   9700    NaN

# %%
car_csv.fillna({"Seats":5},inplace=True)

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   7000    5.0
# 8  Toyota  White          60000      4   6250    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %%
#car_csv["Price"]=car_csv["Price"].str.replace("$","").str.replace(",","").astype(float).astype(int)

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   7000    5.0
# 8  Toyota  White          60000      4   6250    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %%
fuel_eco=[5,8,9,6.7,3,4.5,6,5.3,6,5]
car_csv["fuel_eco"]=pd.Series(fuel_eco)

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco
# 0  Toyota  White         150043      4   4000    5.0       5.0
# 1   Honda    Red          87899      4   5000    5.0       8.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0
# 3     BMW  Black          11179      5  22000    5.0       6.7
# 4  Nissan  White         213095      4   3500    5.0       3.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3
# 8  Toyota  White          60000      4   6250    5.0       6.0
# 9  Nissan  White          31600      4   9700    5.0       5.0

# %%
car_csv["fuel used (L)"]=car_csv["Odometer (KM)"]*car_csv["fuel_eco"]

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv.to_csv("car_sales.csv",index=0)

# %%
# !ls
# Out:
# 11.4 6-step-ml-framework.png       gs_clf_data.joblib
# Data                               gs_clf_data.pkl
# Introduction to Matplotlib.ipynb   images
# Introduction to scikit-Learn.ipynb introduction_to_numpy.ipynb
# Scikit-Learn-data                  introduction_to_pandas.ipynb
# car_miss_drop.csv                  matplotlib-exercises.ipynb
# car_sales.csv                      new_car_sales.csv
# env                                numpy-exercises.ipynb
# example notebook.ipynb             pandas-exercises.ipynb

# %%
pd.read_csv("car_sales.csv")
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv["fuel used"]=car_csv["Odometer (KM)"]*car_csv["fuel_eco"]

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)  \
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0
#
#    fuel used
# 0   750215.0
# 1   703192.0
# 2   292941.0
# 3    74899.3
# 4   639285.0
# 5   446458.5
# ...

# %%
car_csv["fuel used"].dropna()
# Out:
# 0    750215.0
# 1    703192.0
# 2    292941.0
# 3     74899.3
# 4    639285.0
# 5    446458.5
# 6    274188.0
# 7    290111.4
# 8    360000.0
# 9    158000.0
# Name: fuel used, dtype: float64

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)  \
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0
#
#    fuel used
# 0   750215.0
# 1   703192.0
# 2   292941.0
# 3    74899.3
# 4   639285.0
# 5   446458.5
# ...

# %%
car_csv.drop("fuel used" ,axis=1,inplace=True)

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv.Doors.dtype
# Out:
# dtype('int64')

# %%
car_csv["Make"].sample(frac=1)
# Out:
# 8    Toyota
# 0    Toyota
# 2    Toyota
# 6     Honda
# 1     Honda
# 7     Honda
# 5    Toyota
# 9    Nissan
# 4    Nissan
# 3       BMW
# Name: Make, dtype: object

# %%
car_csv["Make"].sample(frac=1)
# Out:
# 6     Honda
# 3       BMW
# 1     Honda
# 4    Nissan
# 0    Toyota
# 5    Toyota
# 9    Nissan
# 8    Toyota
# 7     Honda
# 2    Toyota
# Name: Make, dtype: object

# %% [markdown]
# SET_INDEX AND  RESET_INDEX ( set_index(), reset_index)

# %%
car_csv.set_index("Make",inplace=True)

# %%
car_csv
# Out:
#        Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# Make
# Toyota  White         150043      4   4000    5.0       5.0       750215.0
# Honda     Red          87899      4   5000    5.0       8.0       703192.0
# Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# BMW     Black          11179      5  22000    5.0       6.7        74899.3
# Nissan  White         213095      4   3500    5.0       3.0       639285.0
# Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# Honda    Blue          45698      4   7500    5.0       6.0       274188.0
# Honda    Blue          54738      4   7000    5.0       5.3       290111.4
# Toyota  White          60000      4   6250    5.0       6.0       360000.0
# Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv.plot();

# %%
car_csv.reset_index(inplace=True)

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %%
car_csv.replace(4,4)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 1   Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3     BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 5  Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6   Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7   Honda   Blue          54738      4   7000    5.0       5.3       290111.4
# 8  Toyota  White          60000      4   6250    5.0       6.0       360000.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0

# %% [markdown]
# REPLACE #replace

# %% [markdown]
# car_csv.replace({"column_name":"value to be replaced"},"value to place")

# %% [raw]
# car_csv.replace({"value to be replaced":"value to be placed"})

# %% [markdown]
# car_csv.replace(["series of values"],["to this values"])

# %%
car_csv.replace(["Honda","White"],["Ferrari","Grey"])
# Out:
#       Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0   Toyota   Grey         150043      4   4000    5.0       5.0       750215.0
# 1  Ferrari    Red          87899      4   5000    5.0       8.0       703192.0
# 2   Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# 3      BMW  Black          11179      5  22000    5.0       6.7        74899.3
# 4   Nissan   Grey         213095      4   3500    5.0       3.0       639285.0
# 5   Toyota  Green          99213      4   4500    5.0       4.5       446458.5
# 6  Ferrari   Blue          45698      4   7500    5.0       6.0       274188.0
# 7  Ferrari   Blue          54738      4   7000    5.0       5.3       290111.4
# 8   Toyota   Grey          60000      4   6250    5.0       6.0       360000.0
# 9   Nissan   Grey          31600      4   9700    5.0       5.0       158000.0

# %% [markdown]
# Group_by

# %%
k=car_csv.groupby("Make")

# %%
k

# %%
for a ,b in k:
    print(a,len(b))
    print(b)
    print()
# Out:
# BMW 1
#   Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 3  BMW  Black          11179      5  22000    5.0       6.7        74899.3
#
# Honda 3
#     Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 1  Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 6  Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7  Honda   Blue          54738      4   7000    5.0       5.3       290111.4
#
# Nissan 2
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 4  Nissan  White         213095      4   3500    5.0       3.0       639285.0
# 9  Nissan  White          31600      4   9700    5.0       5.0       158000.0
#
# Toyota 4
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 0  Toyota  White         150043      4   4000    5.0       5.0       750215.0
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0
# ...

# %%
k.get_group("Honda")
# Out:
#     Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 1  Honda    Red          87899      4   5000    5.0       8.0       703192.0
# 6  Honda   Blue          45698      4   7500    5.0       6.0       274188.0
# 7  Honda   Blue          54738      4   7000    5.0       5.3       290111.4

# %%
car_csv.groupby("Doors").get_group(3)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_eco  fuel used (L)
# 2  Toyota   Blue          32549      3   7000    5.0       9.0       292941.0

# %%
india=pd.DataFrame({"city":["vijag","vijayanagaram","srikakulam"],"temperature":[40,38,37],"humidity":[60,50,55]})
india
# Out:
#             city  temperature  humidity
# 0          vijag           40        60
# 1  vijayanagaram           38        50
# 2     srikakulam           37        55

# %%
us=pd.DataFrame({"city":["washigton city","california","paris"],"temperature":[20,19,17],"humidity":[23,23,35]})
us
# Out:
#              city  temperature  humidity
# 0  washigton city           20        23
# 1      california           19        23
# 2           paris           17        35

# %%
pd.concat([india,us]).reset_index()
# Out:
#    index            city  temperature  humidity
# 0      0           vijag           40        60
# 1      1   vijayanagaram           38        50
# 2      2      srikakulam           37        55
# 3      0  washigton city           20        23
# 4      1      california           19        23
# 5      2           paris           17        35

# %%
pd.concat([india,us],ignore_index=1)
# Out:
#              city  temperature  humidity
# 0           vijag           40        60
# 1   vijayanagaram           38        50
# 2      srikakulam           37        55
# 3  washigton city           20        23
# 4      california           19        23
# 5           paris           17        35

# %%
df=pd.concat([india,us],keys=["india","us"])  #both ignore_index and keys don't work together
df,df.index
# Out:
# (                   city  temperature  humidity
#  india 0           vijag           40        60
#        1   vijayanagaram           38        50
#        2      srikakulam           37        55
#  us    0  washigton city           20        23
#        1      california           19        23
#        2           paris           17        35,
#  MultiIndex([('india', 0),
#              ('india', 1),
#              ('india', 2),
#              (   'us', 0),
#              (   'us', 1),
#              (   'us', 2)],
#             ))

# %%
df.loc["india"]
# Out:
#             city  temperature  humidity
# 0          vijag           40        60
# 1  vijayanagaram           38        50
# 2     srikakulam           37        55

# %%
d=pd.Series(["rain","humid","sunny"],name="event",index=[2,0,1])
d
# Out:
# 2     rain
# 0    humid
# 1    sunny
# Name: event, dtype: object

# %%
d
# Out:
# 2     rain
# 0    humid
# 1    sunny
# Name: event, dtype: object

# %%
d=d.sort_index

# %%
d
# Out:
# <bound method Series.sort_index of 2     rain
# 0    humid
# 1    sunny
# Name: event, dtype: object>

# %%
pd.merge(india,us,on="city")
# Out:
# Empty DataFrame
# Columns: [city, temperature_x, humidity_x, temperature_y, humidity_y]
# Index: []

# %%
data1=pd.DataFrame({"city":["delhi","vizag","berhampur"],"temperature":[23,23,34]})
data1
# Out:
#         city  temperature
# 0      delhi           23
# 1      vizag           23
# 2  berhampur           34

# %%
data2=pd.DataFrame({"city":["delhi","berhampur","vizag","mumbai"],"humid":[23,53,43,24]},index=[2,1,3,0])
data2
# Out:
#         city  humid
# 2      delhi     23
# 1  berhampur     53
# 3      vizag     43
# 0     mumbai     24

# %%
pd.merge(data1,data2,on="city")
# Out:
#         city  temperature  humid
# 0      delhi           23     23
# 1      vizag           23     43
# 2  berhampur           34     53

# %% [markdown]
# inner joints , left , right , outer

# %%
pd.merge(data1,data2,on="city",how="left",indicator=True)
# Out:
#         city  temperature  humid _merge
# 0      delhi           23     23   both
# 1      vizag           23     43   both
# 2  berhampur           34     53   both
